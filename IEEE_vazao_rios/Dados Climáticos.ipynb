# %%
from glob import glob
from collections import defaultdict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
table = pd.read_csv('./dados/clima/machado.csv', parse_dates=['Data'], index_col='Data', sep=';')

# %%
table.columns
# Out:
# Index(['Estacao', 'Hora', 'DirecaoVento', 'VelocidadeVentoMedia',
#        'VelocidadeVentoMaximaMedia', 'EvaporacaoPiche', 'EvapoBHPotencial',
#        'EvapoBHReal', 'InsolacaoTotal', 'NebulosidadeMedia',
#        'NumDiasPrecipitacao', 'PrecipitacaoTotal', 'PressaoNivelMarMedia',
#        'PressaoMedia', 'TempMaximaMedia', 'TempCompensadaMedia',
#        'TempMinimaMedia', 'UmidadeRelativaMedia', 'VisibilidadeMedia',
#        'Unnamed: 20'],
#       dtype='object')

# %%
table
# Out:
#             Estacao  Hora  DirecaoVento  VelocidadeVentoMedia  \
# Data
# 1961-09-30    83683     0           0.0              0.202247
# 1961-10-31    83683     0           0.0              0.397849
# 1961-11-30    83683     0           0.0              0.311111
# 1961-12-31    83683     0           0.0              0.311828
# 1962-01-31    83683     0          27.0              0.451613
# 1962-02-28    83683     0          27.0              0.345238
# 1962-03-31    83683     0           0.0              0.494624
# 1962-04-30    83683     0           0.0              0.133333
# 1962-05-31    83683     0           0.0              0.591398
# 1962-06-30    83683     0           0.0              0.477778
# 1962-07-31    83683     0           0.0              0.408602
# 1962-08-31    83683     0           0.0              0.494624
# 1962-09-30    83683     0           NaN                   NaN
# 1962-10-31    83683     0           0.0              1.641304
# ...

# %%
table.isna().sum()
# Out:
# Estacao                         0
# Hora                            0
# DirecaoVento                    7
# VelocidadeVentoMedia           12
# VelocidadeVentoMaximaMedia      5
# EvaporacaoPiche                21
# EvapoBHPotencial              440
# EvapoBHReal                   440
# InsolacaoTotal                 35
# NebulosidadeMedia               6
# NumDiasPrecipitacao           132
# PrecipitacaoTotal               0
# PressaoNivelMarMedia          619
# PressaoMedia                    4
# TempMaximaMedia                 6
# TempCompensadaMedia            13
# TempMinimaMedia                 4
# UmidadeRelativaMedia           20
# VisibilidadeMedia             619
# Unnamed: 20                   619
# dtype: int64

# %%
table.loc[:,table.isna().sum() < 30]
# Out:
#             Estacao  Hora  DirecaoVento  VelocidadeVentoMedia  \
# Data
# 1961-09-30    83683     0           0.0              0.202247
# 1961-10-31    83683     0           0.0              0.397849
# 1961-11-30    83683     0           0.0              0.311111
# 1961-12-31    83683     0           0.0              0.311828
# 1962-01-31    83683     0          27.0              0.451613
# 1962-02-28    83683     0          27.0              0.345238
# 1962-03-31    83683     0           0.0              0.494624
# 1962-04-30    83683     0           0.0              0.133333
# 1962-05-31    83683     0           0.0              0.591398
# 1962-06-30    83683     0           0.0              0.477778
# 1962-07-31    83683     0           0.0              0.408602
# 1962-08-31    83683     0           0.0              0.494624
# 1962-09-30    83683     0           NaN                   NaN
# 1962-10-31    83683     0           0.0              1.641304
# ...

# %%
table.loc[:'2012',['VelocidadeVentoMedia','VelocidadeVentoMaximaMedia','EvaporacaoPiche','NebulosidadeMedia','PrecipitacaoTotal','TempMaximaMedia','TempCompensadaMedia', 'TempMinimaMedia', 'UmidadeRelativaMedia']]
# Out:
#             VelocidadeVentoMedia  VelocidadeVentoMaximaMedia  EvaporacaoPiche  \
# Data
# 1961-09-30              0.202247                         2.0            145.9
# 1961-10-31              0.397849                         3.0            127.6
# 1961-11-30              0.311111                         2.0             83.1
# 1961-12-31              0.311828                         2.0             58.9
# 1962-01-31              0.451613                         4.0             57.7
# 1962-02-28              0.345238                         4.0             44.7
# 1962-03-31              0.494624                         4.0             59.4
# 1962-04-30              0.133333                         1.0             66.3
# 1962-05-31              0.591398                         3.0             67.3
# 1962-06-30              0.477778                         1.0             53.2
# 1962-07-31              0.408602                         3.0             84.5
# ...

# %%
table.loc[:'2012',['VelocidadeVentoMedia','VelocidadeVentoMaximaMedia','EvaporacaoPiche','NebulosidadeMedia','PrecipitacaoTotal','TempMaximaMedia','TempCompensadaMedia', 'TempMinimaMedia', 'UmidadeRelativaMedia']].interpolate(limit_direction='both')
# Out:
#             VelocidadeVentoMedia  VelocidadeVentoMaximaMedia  EvaporacaoPiche  \
# Data
# 1961-09-30              0.202247                         2.0            145.9
# 1961-10-31              0.397849                         3.0            127.6
# 1961-11-30              0.311111                         2.0             83.1
# 1961-12-31              0.311828                         2.0             58.9
# 1962-01-31              0.451613                         4.0             57.7
# 1962-02-28              0.345238                         4.0             44.7
# 1962-03-31              0.494624                         4.0             59.4
# 1962-04-30              0.133333                         1.0             66.3
# 1962-05-31              0.591398                         3.0             67.3
# 1962-06-30              0.477778                         1.0             53.2
# 1962-07-31              0.408602                         3.0             84.5
# ...

# %%
table1 = pd.read_csv('./dados/clima/belo-horizonte.csv', parse_dates=['Data'], index_col='Data', sep=';')
table1.loc[:'2012',['VelocidadeVentoMedia','VelocidadeVentoMaximaMedia','EvaporacaoPiche','NebulosidadeMedia','PrecipitacaoTotal','TempMaximaMedia','TempCompensadaMedia', 'TempMinimaMedia', 'UmidadeRelativaMedia']].resample('M').mean().interpolate(limit_direction='both')
# Out:
#             VelocidadeVentoMedia  VelocidadeVentoMaximaMedia  EvaporacaoPiche  \
# Data
# 1961-01-31              1.285870                         5.0             37.5
# 1961-02-28              1.533333                         9.0             64.3
# 1961-03-31              2.334783                        10.6             76.7
# 1961-04-30              2.183333                         8.0             83.5
# 1961-05-31              1.683696                         5.0             79.1
# 1961-06-30              2.666292                         8.0             78.2
# 1961-07-31              2.220879                         6.0             96.6
# 1961-08-31              2.244086                         6.5            134.6
# 1961-09-30              2.154444                         9.0            164.7
# 1961-10-31              3.575269                         7.5            139.9
# 1961-11-30              1.904444                         8.2            103.2
# ...

# %%
table2 = pd.read_csv('./dados/clima/caldas.csv', parse_dates=['Data'], index_col='Data', sep=';')
table2.loc[:'2012',['VelocidadeVentoMedia','VelocidadeVentoMaximaMedia','EvaporacaoPiche','NebulosidadeMedia','PrecipitacaoTotal','TempMaximaMedia','TempCompensadaMedia', 'TempMinimaMedia', 'UmidadeRelativaMedia']].resample('M').mean().interpolate(limit_direction='both')
# Out:
#             VelocidadeVentoMedia  VelocidadeVentoMaximaMedia  EvaporacaoPiche  \
# Data
# 1961-01-31              1.285870                         5.0             37.5
# 1961-02-28              1.533333                         9.0             64.3
# 1961-03-31              2.334783                        10.6             76.7
# 1961-04-30              2.183333                         8.0             83.5
# 1961-05-31              1.683696                         5.0             79.1
# 1961-06-30              2.666292                         8.0             78.2
# 1961-07-31              2.220879                         6.0             96.6
# 1961-08-31              2.244086                         6.5            134.6
# 1961-09-30              2.154444                         9.0            164.7
# 1961-10-31              3.575269                         7.5            139.9
# 1961-11-30              1.904444                         8.2            103.2
# ...

# %%
table3 = pd.read_csv('./dados/clima/campos-do-jordao.csv', parse_dates=['Data'], index_col='Data', sep=';')
table3.loc[:'2012',['VelocidadeVentoMedia','VelocidadeVentoMaximaMedia','EvaporacaoPiche','NebulosidadeMedia','PrecipitacaoTotal','TempMaximaMedia','TempCompensadaMedia', 'TempMinimaMedia', 'UmidadeRelativaMedia']].resample('M').mean().interpolate(limit_direction='both')
# Out:
#             VelocidadeVentoMedia  VelocidadeVentoMaximaMedia  EvaporacaoPiche  \
# Data
# 1961-01-31              2.445652                         7.0            29.90
# 1961-02-28              1.761905                         5.0            30.50
# 1961-03-31              1.946237                         5.0            40.70
# 1961-04-30              1.905618                         5.0            38.80
# 1961-05-31              1.344086                         5.0            49.00
# 1961-06-30              1.566667                         5.0            43.40
# 1961-07-31              1.483871                         5.0            61.40
# 1961-08-31              1.640812                         7.0            82.40
# 1961-09-30              1.797753                         9.0           103.40
# 1961-10-31              2.204301                         5.0            83.80
# 1961-11-30              2.400000                         7.0            51.20
# ...

# %%
table4 = pd.read_csv('./dados/clima/lavras.csv', parse_dates=['Data'], index_col='Data', sep=';')
table4.loc[:'2012',['VelocidadeVentoMedia','VelocidadeVentoMaximaMedia','EvaporacaoPiche','NebulosidadeMedia','PrecipitacaoTotal','TempMaximaMedia','TempCompensadaMedia', 'TempMinimaMedia', 'UmidadeRelativaMedia']].resample('M').mean().interpolate(limit_direction='both')
# Out:
#             VelocidadeVentoMedia  VelocidadeVentoMaximaMedia  EvaporacaoPiche  \
# Data
# 1961-01-31              1.858696                    5.000000        33.400000
# 1961-02-28              1.734940                    5.000000        33.300000
# 1961-03-31              1.739130                    5.000000        47.900000
# 1961-04-30              1.622222                    5.000000        46.100000
# 1961-05-31              1.720430                    5.000000        44.300000
# 1961-06-30              1.744444                    5.000000        45.400000
# 1961-07-31              1.743189                    5.000000        68.700000
# 1961-08-31              1.741935                    5.000000        92.000000
# 1961-09-30              1.955556                    7.000000       116.800000
# 1961-10-31              1.924731                    5.000000        94.500000
# 1961-11-30              1.588889                    7.000000        68.500000
# ...

# %%
table5 = pd.read_csv('./dados/clima/machado.csv', parse_dates=['Data'], index_col='Data', sep=';')
table5.loc[:'2012',['VelocidadeVentoMedia','VelocidadeVentoMaximaMedia','EvaporacaoPiche','NebulosidadeMedia','PrecipitacaoTotal','TempMaximaMedia','TempCompensadaMedia', 'TempMinimaMedia', 'UmidadeRelativaMedia']].resample('M').mean().interpolate(limit_direction='both')
# Out:
#             VelocidadeVentoMedia  VelocidadeVentoMaximaMedia  EvaporacaoPiche  \
# Data
# 1961-01-31              0.451613                         4.0             57.7
# 1961-02-28              0.345238                         4.0             44.7
# 1961-03-31              0.494624                         4.0             59.4
# 1961-04-30              0.133333                         1.0             66.3
# 1961-05-31              0.591398                         3.0             67.3
# 1961-06-30              0.477778                         1.0             53.2
# 1961-07-31              0.408602                         3.0             84.5
# 1961-08-31              0.494624                         5.0            104.6
# 1961-09-30              0.202247                         2.0            145.9
# 1961-10-31              0.397849                         3.0            127.6
# 1961-11-30              0.311111                         2.0             83.1
# ...

# %%
table6 = pd.read_csv('./dados/clima/resende.csv', parse_dates=['Data'], index_col='Data', sep=';')
table6.loc[:'2012',['VelocidadeVentoMedia','VelocidadeVentoMaximaMedia','EvaporacaoPiche','NebulosidadeMedia','PrecipitacaoTotal','TempMaximaMedia','TempCompensadaMedia', 'TempMinimaMedia', 'UmidadeRelativaMedia']].resample('M').mean().interpolate(limit_direction='both')
# Out:
#             VelocidadeVentoMedia  VelocidadeVentoMaximaMedia  EvaporacaoPiche  \
# Data
# 1961-01-31              0.290217                        4.80            53.90
# 1961-02-28              0.502381                        8.10            49.70
# 1961-03-31              0.701075                        6.80            58.00
# 1961-04-30              0.477778                        6.10            52.40
# 1961-05-31              0.336559                        6.80            50.30
# 1961-06-30              0.602222                        8.70            51.80
# 1961-07-31              0.762366                        7.60            72.50
# 1961-08-31              1.040860                        7.60            95.70
# 1961-09-30              1.630000                       11.30           115.90
# 1961-10-31              2.120430                       11.30           123.00
# 1961-11-30              1.280000                       11.30            88.10
# ...

# %%
table7 = pd.read_csv('./dados/clima/sao-carlos.csv', parse_dates=['Data'], index_col='Data', sep=';')
table7.loc[:'2012',['VelocidadeVentoMedia','VelocidadeVentoMaximaMedia','EvaporacaoPiche','NebulosidadeMedia','PrecipitacaoTotal','TempMaximaMedia','TempCompensadaMedia', 'TempMinimaMedia', 'UmidadeRelativaMedia']].resample('M').mean().interpolate(limit_direction='both')
# Out:
#             VelocidadeVentoMedia  VelocidadeVentoMaximaMedia  EvaporacaoPiche  \
# Data
# 1961-01-31              2.586957                     6.00000            69.70
# 1961-02-28              2.785714                     5.00000            60.90
# 1961-03-31              2.763441                     6.00000           101.00
# 1961-04-30              2.668889                     5.00000            99.00
# 1961-05-31              2.903226                     6.00000            98.20
# 1961-06-30              3.255556                     6.00000           113.50
# 1961-07-31              3.096774                     6.00000           170.10
# 1961-08-31              3.161290                     6.00000           214.30
# 1961-09-30              3.391111                     6.00000           237.70
# 1961-10-31              3.397849                     6.00000           182.50
# 1961-11-30              3.062222                     6.00000           130.90
# ...

# %%
table8 = pd.read_csv('./dados/clima/sao-lourenco.csv', parse_dates=['Data'], index_col='Data', sep=';')
table8.loc[:'2012',['VelocidadeVentoMedia','VelocidadeVentoMaximaMedia','EvaporacaoPiche','NebulosidadeMedia','PrecipitacaoTotal','TempMaximaMedia','TempCompensadaMedia', 'TempMinimaMedia', 'UmidadeRelativaMedia']].resample('M').mean().interpolate(limit_direction='both')
# Out:
#             VelocidadeVentoMedia  VelocidadeVentoMaximaMedia  EvaporacaoPiche  \
# Data
# 1961-01-31              0.682609                         3.7             48.0
# 1961-02-28              0.578571                         9.5             39.5
# 1961-03-31              1.055914                         6.2             58.4
# 1961-04-30              0.823333                         3.2             47.4
# 1961-05-31              0.686022                         3.7             45.4
# 1961-06-30              0.765556                         4.3             47.6
# 1961-07-31              0.824731                         3.3             65.5
# 1961-08-31              0.797849                         3.4             82.5
# 1961-09-30              1.122222                         4.9            108.5
# 1961-10-31              0.852688                         5.5             93.4
# 1961-11-30              0.916667                         3.9             60.4
# ...

# %%
pasta_dados = 'dados/clima'
#atributos = ['VelocidadeVentoMedia','VelocidadeVentoMaximaMedia','EvaporacaoPiche','NebulosidadeMedia','PrecipitacaoTotal','TempMaximaMedia','TempCompensadaMedia', 'TempMinimaMedia', 'UmidadeRelativaMedia']
atributos = ['EvaporacaoPiche','NebulosidadeMedia','PrecipitacaoTotal','TempCompensadaMedia', 'UmidadeRelativaMedia']

def carrega_clima(pasta_dados):
    quant_meses = 624
    dados = np.zeros((quant_meses, len(atributos)*len(glob('dados/clima/*.csv'))))
    for i, arquivo in enumerate(glob(pasta_dados+'/*.csv')):
        print(arquivo, end=', ')
        tabela = pd.read_csv('./dados/clima/sao-lourenco.csv', parse_dates=['Data'], index_col='Data', sep=';')
        valores = tabela.loc[:'2012',atributos].resample('M').mean().interpolate(limit_direction='both').values
        assert(valores.shape[0] == quant_meses)
        dados[:,i*len(atributos):(i+1)*len(atributos)] = valores[:,:]
    return dados

dados_clima = carrega_clima(pasta_dados)
# Out:
# dados/clima/sao-carlos.csv, dados/clima/resende.csv, dados/clima/sao-lourenco.csv, dados/clima/lavras.csv, dados/clima/belo-horizonte.csv, dados/clima/campos-do-jordao.csv, dados/clima/machado.csv, dados/clima/caldas.csv,

# %%
dados_clima.shape
# Out:
# (624, 40)
